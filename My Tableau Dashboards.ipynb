# %% [markdown]
# # ПРИМЕРЫ ДАШБОРДОВ TABLEAU

# %% [markdown]
# ДАНИЛЬЧЕНКО ВАДИМ

# %%
# импортируем библиотеки
from IPython.display import Image

# %% [markdown]
# дашборд показывает отток в заисимости от управляемых элементов, а также подсвечивает проблемные зоны
#
# параметром можно выбрать метрику
#
# использован LOD для некоторых метрик

# %%
Image(filename=r'Tableau Snapshots\10.png')

# %% [markdown]
# Дашборд отображает выполнение показателя по юнитам
#
# также карта разделена на несколько интересующих зон, каждая из которых является управляемым элементом

# %%
Image(filename=r'Tableau Snapshots/9.png')

# %% [markdown]
# Дашборд ниже показывает показатели производительности по команде
#
# использованы "actions" для навигации по группе книг
#
# также для каждого сотрудника отображена фотография

# %%
Image(filename=r'Tableau Snapshots/8.png')

# %% [markdown]
# В данном дашборде использованы данные, подготовленные "custom sql"
#
# в столбчатой диаграмме объединены несколько measures, оси синхронизированы
#
# точка показывает общее значение, на остальных элементах доли, посчитанные с помощью table calculations
#
# диаграмма Ганта отображает выполнение KPI по элементу (просроченные и не закрытые становятся красными, остальные зелеными,
#                                                        также делятся на цвета от запланированного времени)
#
# отображено облако тэгов

# %%
Image(filename=r'Tableau Snapshots/7.png')

# %% [markdown]
# ниже отображена воронка (AS IS), а таже bullet chart с подсветкой показателей, превышающих установленные таргеты

# %%
Image(filename=r'Tableau Snapshots/6.png')

# %% [markdown]
# На данном дашборде использованы элементы инфографики - показывает ключевые метрики по тематике и их производные
#
# связь между различными источниками с помощью blended data
#
# расчет некоторых элементов осуществляется на разных уровнях, часть из них рассчитана отношением текущего периода к начальному, которые верхнеуровнево скрыты фильтром
#
# также использованы элементы "actions"

# %%
Image(filename=r'Tableau Snapshots/5.png')

# %% [markdown]
# дашборд ниже является титульным и содержит ключевую информацию, разделенную на блоки
#
# элементы инфографики содержат ссылки, срабатывают при клике

# %%
Image(filename=r'Tableau Snapshots/3.png')

# %% [markdown]
# данный дашбод отображает отношение метрик по в зависимости от времени старта мероприятия

# %%
Image(filename=r'Tableau Snapshots/2.png')
